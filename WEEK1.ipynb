# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhilash0201/Futyrecart-infosys/blob/main/merging_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New Section

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
product1=pd.read_excel(r'/content/drive/MyDrive/infosys/ProductA.xlsx')
product1.head()
# Out:
#    Day Index  Quantity
# 0 2021-12-01        14
# 1 2021-12-02        10
# 2 2021-12-03        13
# 3 2021-12-04        22
# 4 2021-12-05        33
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_24['Quantity'].plot(kind='hist', bins=20, title='Quantity')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Day Index']
#   ys = series['Quantity']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_25.sort_values('Day Index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Day Index')
# _ = plt.ylabel('Quantity')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Day Index']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Day Index'}, axis=1)
#               .sort_values('Day Index', ascending=True))
#   xs = counted['Day Index']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_26.sort_values('Day Index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Day Index')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_27['Quantity'].plot(kind='line', figsize=(8, 4), title='Quantity')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
facebook_impressions=pd.read_excel(r'/content/drive/MyDrive/infosys/ProductA_fb_impressions.xlsx')
facebook_impressions.head()
# Out:
#    Day Index  Impressions
# 0 2021-12-01          620
# 1 2021-12-02          890
# 2 2021-12-03          851
# 3 2021-12-04          881
# 4 2021-12-05          678
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_20['Impressions'].plot(kind='hist', bins=20, title='Impressions')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Day Index']
#   ys = series['Impressions']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_21.sort_values('Day Index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Day Index')
# _ = plt.ylabel('Impressions')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Day Index']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Day Index'}, axis=1)
#               .sort_values('Day Index', ascending=True))
#   xs = counted['Day Index']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_22.sort_values('Day Index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Day Index')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_23['Impressions'].plot(kind='line', figsize=(8, 4), title='Impressions')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
google_clicks=pd.read_excel(r'/content/drive/MyDrive/infosys/ProductA_google_clicks.xlsx')
google_clicks.head()
# Out:
#    Day Index  Clicks
# 0 2021-12-01     445
# 1 2021-12-02     433
# 2 2021-12-03     424
# 3 2021-12-04     427
# 4 2021-12-05     451
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_16['Clicks'].plot(kind='hist', bins=20, title='Clicks')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Day Index']
#   ys = series['Clicks']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_17.sort_values('Day Index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Day Index')
# _ = plt.ylabel('Clicks')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Day Index']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Day Index'}, axis=1)
#               .sort_values('Day Index', ascending=True))
#   xs = counted['Day Index']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_18.sort_values('Day Index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Day Index')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_19['Clicks'].plot(kind='line', figsize=(8, 4), title='Clicks')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# merging using left outer join on 'Day Index'
mergeddata = pd.merge(producta,facebook_impressions , on="Day Index", how="left")
masterdata = pd.merge(mergeddata,google_clicks, on="Day Index", how="left")
masterdata.head()
# Out:
#    Day Index  Quantity  Impressions  Clicks
# 0 2021-12-01        14          620     445
# 1 2021-12-02        10          890     433
# 2 2021-12-03        13          851     424
# 3 2021-12-04        22          881     427
# 4 2021-12-05        33          678     451
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_28['Quantity'].plot(kind='hist', bins=20, title='Quantity')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_29['Impressions'].plot(kind='hist', bins=20, title='Impressions')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_30['Clicks'].plot(kind='hist', bins=20, title='Clicks')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_31.plot(kind='scatter', x='Quantity', y='Impressions', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_32.plot(kind='scatter', x='Impressions', y='Clicks', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Day Index']
#   ys = series['Quantity']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_33.sort_values('Day Index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Day Index')
# _ = plt.ylabel('Quantity')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Day Index']
#   ys = series['Impressions']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_34.sort_values('Day Index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Day Index')
# _ = plt.ylabel('Impressions')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Day Index']
#   ys = series['Clicks']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_35.sort_values('Day Index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Day Index')
# _ = plt.ylabel('Clicks')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Day Index']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Day Index'}, axis=1)
#               .sort_values('Day Index', ascending=True))
#   xs = counted['Day Index']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_36.sort_values('Day Index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Day Index')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_37['Quantity'].plot(kind='line', figsize=(8, 4), title='Quantity')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_38['Impressions'].plot(kind='line', figsize=(8, 4), title='Impressions')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_39['Clicks'].plot(kind='line', figsize=(8, 4), title='Clicks')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
print(masterdata)
# Out:
#      Day Index  Quantity  Impressions  Clicks
# 0   2021-12-01        14          620     445
# 1   2021-12-02        10          890     433
# 2   2021-12-03        13          851     424
# 3   2021-12-04        22          881     427
# 4   2021-12-05        33          678     451
# ..         ...       ...          ...     ...
# 207 2022-06-26        13         1218     114
# 208 2022-06-27        16         1311     106
# 209 2022-06-28        13          885     109
# 210 2022-06-29        16         1000      60
# 211 2022-06-30         8          875      65
#
# [212 rows x 4 columns]

# %%
file_path = '/content/drive/My Drive/infosys/ProductA_masterdata.xlsx'
masterdata.to_excel(file_path, index=False)
print(f"File saved to {file_path}")
# Out:
# File saved to /content/drive/My Drive/infosys/ProductA_masterdata.xlsx
